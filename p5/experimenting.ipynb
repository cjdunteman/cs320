# %%
import land
import sqlite3
import zipfile
import os
import pandas as pd

print(dir(land))

c = land.open("images")
c.image_year("area165.npy")
# c.close()
# Out:
# ['Connection', 'ZipFile', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'io', 'np', 'open', 'os', 'pd', 'sqlite3', 'zipfile']
# 2016

# %%
assert os.path.exists("images.db")
c = sqlite3.connect("images.db")
places_df = pd.read_sql("SELECT * FROM places", c)
places_df
# Out:
#      place_id        name        lat        lon
# 0         100       samp0  42.821935 -88.151540
# 1         101       samp1  45.170729 -88.397469
# 2         102       samp2  44.941672 -89.897391
# 3         103       samp3  43.101989 -88.899274
# 4         104       samp4  46.618371 -92.127578
# ..        ...         ...        ...        ...
# 105       205    appleton  44.280000 -88.390000
# 106       206    waukesha  43.010000 -88.250000
# 107       207     oshkosh  44.020000 -88.560000
# 108       208   eauclaire  44.820000 -91.490000
# 109       209  janesville  42.690000 -89.010000
#
# [110 rows x 4 columns]

# %%
places_df = places_df["name"][0:100]
places_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-160c9ba51719> in <module>
# ----> 1 places_df = places_df["name"][0:100]
#       2 places_df
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4402         k = self._convert_scalar_indexer(k, kind="getitem")
#    4403         try:
# -> 4404             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4405         except KeyError as e1:
#    4406             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'name'

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.set_ylabel("Deciduous Forest %")
ax.set_xlabel("Latitude")
c.lat_regression(41, ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-a5e55322597b> in <module>
#       4 ax.set_ylabel("Deciduous Forest %")
#       5 ax.set_xlabel("Latitude")
# ----> 6 c.lat_regression(41, ax)
#
# AttributeError: 'sqlite3.Connection' object has no attribute 'lat_regression'

# %%
from zipfile import ZipFile
import io
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap
import collections

use_code=41
with ZipFile("images.zip") as zf:
    count = 0
    total = 0
    for file in zf.namelist():
        with zf.open(file) as f:
            buf = io.BytesIO(f.read())
            place = np.load(buf)
            count += np.count_nonzero(place == use_code)
            total += np.size(place)
percent = count / total
percent
# Out:
# area0.npy
# area1.npy
# area2.npy
# area3.npy
# area4.npy
# area5.npy
# area6.npy
# area7.npy
# area8.npy
# area9.npy
# area10.npy
# area11.npy
# area12.npy
# area13.npy
# area14.npy
# area15.npy
# area16.npy
# area17.npy
# area18.npy
# area19.npy
# area20.npy
# area21.npy
# area22.npy
# area23.npy
# area24.npy
# area25.npy
# area26.npy
# area27.npy
# area28.npy
# area29.npy
# area30.npy
# area31.npy
# area32.npy
# area33.npy
# area34.npy
# area35.npy
# area36.npy
# area37.npy
# area38.npy
# area39.npy
# area40.npy
# area41.npy
# area42.npy
# area43.npy
# area44.npy
# area45.npy
# area46.npy
# area47.npy
# area48.npy
# area49.npy
# area50.npy
# area51.npy
# area52.npy
# area53.npy
# area54.npy
# area55.npy
# area56.npy
# area57.npy
# area58.npy
# area59.npy
# area60.npy
# area61.npy
# area62.npy
# area63.npy
# area64.npy
# area65.npy
# area66.npy
# area67.npy
# area68.npy
# area69.npy
# area70.npy
# area71.npy
# area72.npy
# area73.npy
# area74.npy
# area75.npy
# area76.npy
# area77.npy
# area78.npy
# area79.npy
# area80.npy
# area81.npy
# area82.npy
# area83.npy
# area84.npy
# area85.npy
# area86.npy
# area87.npy
# area88.npy
# area89.npy
# area90.npy
# area91.npy
# area92.npy
# area93.npy
# area94.npy
# area95.npy
# area96.npy
# area97.npy
# area98.npy
# area99.npy
# area100.npy
# area101.npy
# area102.npy
# area103.npy
# area104.npy
# area105.npy
# area106.npy
# area107.npy
# area108.npy
# area109.npy
# area110.npy
# area111.npy
# area112.npy
# area113.npy
# area114.npy
# area115.npy
# area116.npy
# area117.npy
# area118.npy
# area119.npy
# area120.npy
# area121.npy
# area122.npy
# area123.npy
# area124.npy
# area125.npy
# area126.npy
# area127.npy
# area128.npy
# area129.npy
# area130.npy
# area131.npy
# area132.npy
# area133.npy
# area134.npy
# area135.npy
# area136.npy
# area137.npy
# area138.npy
# area139.npy
# area140.npy
# area141.npy
# area142.npy
# area143.npy
# area144.npy
# area145.npy
# area146.npy
# area147.npy
# area148.npy
# area149.npy
# area150.npy
# area151.npy
# area152.npy
# area153.npy
# area154.npy
# area155.npy
# area156.npy
# area157.npy
# area158.npy
# area159.npy
# area160.npy
# area161.npy
# area162.npy
# area163.npy
# area164.npy
# area165.npy
# area166.npy
# area167.npy
# area168.npy
# area169.npy
# 0.10108428457869634
