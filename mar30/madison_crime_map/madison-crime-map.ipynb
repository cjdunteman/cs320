# %%
import pandas as pd
from datetime import timedelta, datetime, date

# %%
# Filter useful info
df = pd.read_csv("crime.csv")[["IncidentDate", "Address"]]

df.head()
# Out:
#                IncidentDate                                            Address
# 0  2005-10-07T03:33:00.000Z  700 Block of E. Washington Ave.               ...
# 1  2005-03-03T05:42:00.000Z  First St & E Washington Ave                   ...
# 2  2005-03-02T14:30:00.000Z  8 New Berm Court                              ...
# 3  2005-03-03T13:30:00.000Z  4300 Lumley Rd                                ...
# 4  2005-03-04T19:45:00.000Z  211 S. Carroll Street                         ...

# %%
# Convert to datetime
df["IncidentDate"] = pd.to_datetime(df["IncidentDate"])

# %%
# Add day column
df["date"] = df["IncidentDate"].dt.date
df.head()
# Out:
#                IncidentDate  \
# 0 2005-10-07 03:33:00+00:00
# 1 2005-03-03 05:42:00+00:00
# 2 2005-03-02 14:30:00+00:00
# 3 2005-03-03 13:30:00+00:00
# 4 2005-03-04 19:45:00+00:00
#
#                                              Address        date
# 0  700 Block of E. Washington Ave.               ...  2005-10-07
# 1  First St & E Washington Ave                   ...  2005-03-03
# 2  8 New Berm Court                              ...  2005-03-02
# 3  4300 Lumley Rd                                ...  2005-03-03
# 4  211 S. Carroll Street                         ...  2005-03-04

# %%
# Add percent of day column
df["percent"] = (df["IncidentDate"] - df["IncidentDate"].dt.floor("d")) / timedelta(days=1)
df.head()
# Out:
#                IncidentDate  \
# 0 2005-10-07 03:33:00+00:00
# 1 2005-03-03 05:42:00+00:00
# 2 2005-03-02 14:30:00+00:00
# 3 2005-03-03 13:30:00+00:00
# 4 2005-03-04 19:45:00+00:00
#
#                                              Address        date   percent
# 0  700 Block of E. Washington Ave.               ...  2005-10-07  0.147917
# 1  First St & E Washington Ave                   ...  2005-03-03  0.237500
# 2  8 New Berm Court                              ...  2005-03-02  0.604167
# 3  4300 Lumley Rd                                ...  2005-03-03  0.562500
# 4  211 S. Carroll Street                         ...  2005-03-04  0.822917

# %%
df = df[df["date"] == date(2008, 10, 12)].copy()
df
# Out:
#                   IncidentDate                              Address  \
# 2967 2008-10-12 04:26:00+00:00              3019 E. Washington Ave.
# 2968 2008-10-12 08:00:00+00:00                    4300 Doncaster Dr
# 2969 2008-10-12 08:00:00+00:00                        500 State St.
# 2970 2008-10-12 06:30:00+00:00                      123 E. Doty St.
# 2971 2008-10-12 07:10:00+00:00               400 Block N. Henry St.
# 2972 2008-10-12 05:27:00+00:00                      500 N. Lake St.
# 2974 2008-10-12 02:24:00+00:00  E. Johnson Street @ Pinckney Street
# 2979 2008-10-12 23:31:00+00:00                1600 block Troy Drive
# 2980 2008-10-12 05:06:00+00:00            600 block of State Street
# 2982 2008-10-12 05:06:00+00:00       100 block South Randall Avenue
# 2994 2008-10-12 05:58:00+00:00              2400 block Monterey Dr.
#
#             date   percent
# 2967  2008-10-12  0.184722
# 2968  2008-10-12  0.333333
# 2969  2008-10-12  0.333333
# 2970  2008-10-12  0.270833
# 2971  2008-10-12  0.298611
# 2972  2008-10-12  0.227083
# 2974  2008-10-12  0.100000
# 2979  2008-10-12  0.979861
# 2980  2008-10-12  0.212500
# 2982  2008-10-12  0.212500
# 2994  2008-10-12  0.248611

# %%
def get_api_key():
    with open("secret.txt") as f:
        return f.read().strip()

# %%
from shapely.geometry import Point
import requests

# Get lat and long for addr
def get_loc(addr):
    addr += " Madison WI"
    addr = addr.replace(" ", "+") # simple URL encoding
    url = "https://maps.googleapis.com/maps/api/geocode/json?address={}&key={}"
    url = url.format(addr, get_api_key())
    r = requests.get(url) # pay each time this line runs! bad!
    r.raise_for_status()
    coord = r.json()["results"][0]["geometry"]["location"] 
    return Point(coord["lng"], coord["lat"])

print(get_loc("500 State St."))
# Out:
# POINT (-89.3934697 43.074861)

# %%
# Add column with lats and longs of each addr
df["geometry"] = None
for idx in df.index:
    addr = df.loc[idx, "Address"]
    pt = get_loc(addr)
    df.loc[idx, "geometry"] = pt
df.head()
# Out:
#                   IncidentDate                  Address        date   percent  \
# 2967 2008-10-12 04:26:00+00:00  3019 E. Washington Ave.  2008-10-12  0.184722
# 2968 2008-10-12 08:00:00+00:00        4300 Doncaster Dr  2008-10-12  0.333333
# 2969 2008-10-12 08:00:00+00:00            500 State St.  2008-10-12  0.333333
# 2970 2008-10-12 06:30:00+00:00          123 E. Doty St.  2008-10-12  0.270833
# 2971 2008-10-12 07:10:00+00:00   400 Block N. Henry St.  2008-10-12  0.298611
#
#                                    geometry
# 2967         POINT (-89.3419911 43.1037753)
# 2968  POINT (-89.44864729999999 43.0361164)
# 2969          POINT (-89.3934697 43.074861)
# 2970  POINT (-89.38006469999999 43.0743762)
# 2971  POINT (-89.39078479999999 43.0754426)

# %%
import geopandas

# %%
gdf = geopandas.GeoDataFrame(df)
gdf
# Out:
#                   IncidentDate                              Address  \
# 2967 2008-10-12 04:26:00+00:00              3019 E. Washington Ave.
# 2968 2008-10-12 08:00:00+00:00                    4300 Doncaster Dr
# 2969 2008-10-12 08:00:00+00:00                        500 State St.
# 2970 2008-10-12 06:30:00+00:00                      123 E. Doty St.
# 2971 2008-10-12 07:10:00+00:00               400 Block N. Henry St.
# 2972 2008-10-12 05:27:00+00:00                      500 N. Lake St.
# 2974 2008-10-12 02:24:00+00:00  E. Johnson Street @ Pinckney Street
# 2979 2008-10-12 23:31:00+00:00                1600 block Troy Drive
# 2980 2008-10-12 05:06:00+00:00            600 block of State Street
# 2982 2008-10-12 05:06:00+00:00       100 block South Randall Avenue
# 2994 2008-10-12 05:58:00+00:00              2400 block Monterey Dr.
#
#             date   percent                    geometry
# 2967  2008-10-12  0.184722  POINT (-89.34199 43.10378)
# 2968  2008-10-12  0.333333  POINT (-89.44865 43.03612)
# 2969  2008-10-12  0.333333  POINT (-89.39347 43.07486)
# 2970  2008-10-12  0.270833  POINT (-89.38006 43.07438)
# 2971  2008-10-12  0.298611  POINT (-89.39078 43.07544)
# 2972  2008-10-12  0.227083  POINT (-89.39736 43.07490)
# 2974  2008-10-12  0.100000  POINT (-89.38581 43.07767)
# 2979  2008-10-12  0.979861  POINT (-89.36811 43.13369)
# 2980  2008-10-12  0.212500  POINT (-89.39539 43.07490)
# 2982  2008-10-12  0.212500  POINT (-89.40900 43.06666)
# 2994  2008-10-12  0.248611  POINT (-89.36864 43.12460)

# %%
gdf[["percent", "geometry"]].to_file("crime.shp")
